# %%
from numpy import dot
from numpy.linalg import norm
import numpy as np
import pandas as pd
import matplotlib
import pandas_profiling

# %%
import os
print(os.getcwd())
# Out:
# D:\Project\Django\Scripts\server_project\test\owner_project\result

# %%
# 2019년 데이터 Load
df19 = pd.read_excel("D:\Project\Data_set\data2019.xlsx")
df18 = pd.read_excel("D:\Project\Data_set\data2018.xlsx")

df18.head(5)
# Out:
# <bound method NDFrame.head of               회원번호   성명            주민번호                                  주소  \
# 0       0022A00001  이옥성  590318-1000000               경기도 광주시 퇴촌면 천진암로 530
# 1       0072A00001  안성열  581125-1000000       경기도 수원시 팔달구  월드컵로321번길 12-6
# 2       0072A00002  배준택  831121-1000000  부산광역시 영도구  와치로 261 신흥동백 8차 다동 507호
# 3       0072A00003  배민규  821023-1000000                 울산광역시 중구  도화골10길 5
# 4       0072A00006  최금순  340728-2000000   경기도 과천시  별양로 180 주공8단지 809동 1508호
# ...            ...  ...             ...                                 ...
# 234608  U022A22156  이도상  530510-1000000         부산 사하구 구평동  435-259번지 3통 2반
# 234609  U244A00803  배상호  820807-1000000        부산 영도구 동삼동  도개공아파트 1310-205호
# 234610  U244A00804  배규태  830402-1000000                 부산 사하구 구평동  104-2번지
# 234611  U244A00805  김군자  490809-2000000           부산 서구 서대신동2가  250-3번지 남원옥
# 234612  U244A00806  정일선  540801-2000000              부산 서구 서대신동2가  213-6번지
#
#         상태       가입상품        가입일자      최종불입일자  총납입회차  최종불입회차  ...     실입금액  \
# 0       해약  부금2400000  2008-09-08  2016-12-20    100     100  ...   456000
# 1       행사     특240만원  2007-09-28  2012-10-04    100     100  ...  2400000
# 2       보류     특240만원  2007-10-23  2013-05-20    100      68  ...  1632000
# 3       행사     특240만원  2007-10-23  2014-12-31    100     100  ...  2400000
# 4       행사     특240만원  2007-10-31  2016-01-05    100     100  ...  2400000
# ...     ..        ...         ...         ...    ...     ...  ...      ...
# 234608  해약  부금2400000  2009-01-07         NaN    100       0  ...        0
# 234609  해약    부금240만원  2008-12-16  2012-06-29     60      43  ...   480000
# 234610  만기    부금240만원  2008-12-16  2013-11-25     60      60  ...  2400000
# 234611  해약    부금240만원  2008-12-16  2008-12-18     60       1  ...    40000
# 234612  해약    부금240만원  2008-12-16  2009-11-25     60      12  ...   480000
#
#           기간입금액 기간할인액     잔여금액   조합예수잔액  납입방법     담당자   부서  연체횟수  성별
# 0       2400000     0 -1944000        0   CMS  더피플라이프  관리부     0   남
# 1       2400000     0        0        0   CMS  더피플라이프  관리부     0   남
# 2       1632000     0   768000   768000   CMS  더피플라이프  관리부    32   남
# 3       2400000     0        0        0   CMS  더피플라이프  관리부     0   남
# 4       2400000     0        0        0   CMS  더피플라이프  관리부     0   여
# ...         ...   ...      ...      ...   ...     ...  ...   ...  ..
# 234608        0     0  2400000  2400000   CMS  더피플라이프  관리부   100   남
# 234609  1720000     0  -560000   680000   CMS  더피플라이프  관리부    17   남
# 234610  2400000     0        0        0   CMS  더피플라이프  관리부     0   남
# 234611    40000     0  2360000  2360000   CMS  더피플라이프  관리부    59   여
# 234612   480000     0  1920000  1920000   CMS  더피플라이프  관리부    48   여
#
# [234613 rows x 27 columns]>

# %%
print(df19.shape)
df18.shape
# Out:
# (368975, 27)
# (234613, 27)

# %%
# NULL값 제거
df19.dropna(how='any')
df18.dropna(how='any')
print(df19.shape)
print(df18.shape)
# Out:
# (368975, 27)
# (234613, 27)

# %%
df19.columns
# Out:
# Index(['회원번호', '성명', '주민번호', '주소', '상태', '가입상품', '가입일자', '최종불입일자', '총납입회차',
#        '최종불입회차', '이체일', '은행', '계좌번호', '예금주', '상품금액', '총불입액', '해약금액', '실입금액',
#        '기간입금액', '기간할인액', '잔여금액', '조합예수잔액', '납입방법', '담당자', '부서', '연체횟수', '성별'],
#       dtype='object')

# %%
#백업용
df2018 = df18
df2019 = df19

# %%
# 백업
df18 = df2018
df19 = df2019

# %%
# 필요한 columns 
df18 = df18[['회원번호','성명','주민번호','주소','상태', '가입일자','최종불입일자','총납입회차','최종불입회차', '은행', '상품금액','총불입액','잔여금액','연체횟수','성별']]
df19 = df19[['회원번호','성명','주민번호','주소','상태', '가입일자','최종불입일자','총납입회차','최종불입회차', '은행', '상품금액','총불입액','잔여금액','연체횟수','성별']]

# %%
print(df18['상태'].value_counts())
print(df19['상태'].value_counts())
# Out:
# 해약     105100
# 가입     103432
# 만기      10803
# 행사       9472
# 보류       3036
# 미계좌      2072
# 접수        589
# 해지         63
# 보류2        46
# Name: 상태, dtype: int64
# 가입     188240
# 해약     148180
# 행사      11003
# 만기      10782
# 보류       4633
# 해지       2691
# 멤버쉽      1656
# 미계좌      1454
# 접수        298
# 보류2        38
# Name: 상태, dtype: int64

# %%
# '상태' 정리 2019년 데이터 
def transform_status(current_status, flag):
    if current_status == '가입':
        if flag == 0:
            return '만기'
        else:
            return current_status

    elif current_status == '해약':
        if flag == 0:
            return '만기_해약'
        else:
            return current_status

    elif current_status == '미계좌':
        return '해약'

    elif current_status == '보류':
        return '가입'

    elif current_status == '접수':
        return '가입'

    elif current_status == '보류2':
        return '가입'
    
    elif current_status == '멤버쉽':
        return '가입'
    
    elif current_status == '해지':
        return '해약'
    
    else:
        return current_status

# %%
# 상태는 (총납입회차 - 최종불입회차) 의 값을 기준으로 만기_해약 분류
df18['상태'] = df18.apply(lambda x: transform_status(x['상태'], x['총납입회차'] - x['최종불입회차']), axis=1)
df19['상태'] = df19.apply(lambda x: transform_status(x['상태'], x['총납입회차'] - x['최종불입회차']), axis=1)
# Out:
# D:\Project\Django\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# D:\Project\Django\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
print(df18['상태'].value_counts())
print(df19['상태'].value_counts())
# Out:
# 가입       107102
# 해약       103570
# 만기        10804
# 행사         9472
# 만기_해약      3665
# Name: 상태, dtype: int64
# 가입       194862
# 해약       146166
# 행사        11003
# 만기        10785
# 만기_해약      6159
# Name: 상태, dtype: int64

# %%
# 해약 행사 만기_해약 인 사람들의 나이 ? 
def c_age(age, current_status, c_date):
    if current_status == '행사' or current_status == '해약' or current_status == '만기_해약'
        if flag == 0:
            return '만기'
        else:
            return current_status

    elif current_status == '해약':
        if flag == 0:
            return '만기_해약'
        else:

# %%
# 해약일자 기준 나이 
def c_age(idnum, c_date):
    c_date = str(c_date)
    age = (int(c_date[2:4])) - (int(idnum[0:2])) + 100
    return age

print(c_age('590318-1000','2016-12-20'))
# Out:
# 57

# %%
df18.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 234613 entries, 0 to 234612
# Data columns (total 15 columns):
# 회원번호      234613 non-null object
# 성명        234613 non-null object
# 주민번호      234613 non-null object
# 주소        234613 non-null object
# 상태        234613 non-null object
# 가입일자      234613 non-null object
# 최종불입일자    215094 non-null object
# 총납입회차     234613 non-null int64
# 최종불입회차    234613 non-null int64
# 은행        224171 non-null object
# 상품금액      234613 non-null int64
# 총불입액      234613 non-null int64
# 잔여금액      234613 non-null int64
# 연체횟수      234613 non-null int64
# 성별        234613 non-null object
# dtypes: int64(6), object(9)
# memory usage: 26.8+ MB

# %%
# 전처리 함수

# '나이' 계산
def export_age(idnum):
    pre_age = (int(idnum[0:2]))
    if pre_age < 10:
        age = 20 - pre_age
    else:
        age = 120 - pre_age
    return age

# 사람 별 고유 id 뽑기
def transform_id(name, id_num):
    idnum = id_num[0:6]
    return name + idnum

# 연체횟수가 마이너스 인 값(행사값) 정리
def preprocess_event(num):
    if num < 0:
        return -1
    else:
        return num
    
# 진행률 = 최종불입회차 / 총 납입회차
def process_rate(total, last):
    rate = int(last) / int(total)
    return rate

# 성별 전처리
def preprocess_sex(sex):
    if sex =='남':
        return 0
    else:
        return 1

# %%
df = df.dropna(how='any')
df.shape
# Out:
# (344045, 13)

# %%
# 1차 전처리
# 나이는 주민번호로 계산
df['나이'] = df['주민번호'].apply(lambda x : export_age(x))


df['이름번호'] = df.apply(lambda x: transform_id(x['성명'], x['주민번호']), axis=1)

# 연체횟수가 마이너스 인 값 정리 (모두 -1로 통일함)
df['연체횟수'] = df['연체횟수'].apply(lambda x : preprocess_event(x))


df['진행률'] = df.apply(lambda x: process_rate(x['총납입회차'] , x['최종불입회차']), axis=1)
df['성별'] = df['성별'].apply(lambda x : preprocess_sex(x))

# %%
df.to_csv("preprocess_2019.csv", index=False)

# %%
# ------------- 일 단 여기 까지 여기 아래는 아님. --------------------- #

# %%
pr = df.profile_report()
pr.to_file("summary_report_2019.html")
# Out:
# variables:  88%|████████▊ | 15/17 [00:48<00:12,  6.29s/it]

# %%
# 해약금액
def z_score_normalize(value, mean, std):
    normalized = []
    normalized_num = (value - mean) / std
    normalized.append(normalized_num)
    return normalized[0]

# %%
mean = np.mean(list(dfs['해약금액']))
std = np.mean(list(dfs['해약금액']))
dfs['해약금액'] = dfs['해약금액'].apply(lambda x : z_score_normalize(x,mean,std))

# %%
mean = np.mean(list(dfs['연체횟수']))
std = np.mean(list(dfs['연체횟수']))
dfs['연체횟수'] = dfs['연체횟수'].apply(lambda x : z_score_normalize(x,mean,std))

# %%
mean = np.mean(list(dfs['나이']))
std = np.mean(list(dfs['나이']))
dfs['나이'] = dfs['나이'].apply(lambda x : z_score_normalize(x,mean,std))

# %%
mean = np.mean(list(dfs['총불입액']))
std = np.mean(list(dfs['총불입액']))
dfs['총불입액'] = dfs['총불입액'].apply(lambda x : z_score_normalize(x,mean,std))

# %%
dfs['상품금액'] = df2['상품금액']
dfs
# Out:
#               회원번호       회원이름  주소     상품금액      총불입액       해약금액     담당자  \
# 0       0022A00001  이옥성590318  경기  2400000  3.043359  18.730409  더피플라이프
# 1       0072A00001  안성열581125  경기  2400000  3.043359  -1.000000  더피플라이프
# 2       0072A00002  배준택831121  부산  2400000  1.749484  -1.000000  더피플라이프
# 3       0072A00003  배민규821023  울산  2400000  3.043359  -1.000000  더피플라이프
# 4       0072A00006  최금순340728  경기  2400000  3.043359  -1.000000  더피플라이프
# ...            ...        ...  ..      ...       ...        ...     ...
# 234607  U022A22155  조길찬761012  부산  2400000 -0.878699  -1.000000  더피플라이프
# 234609  U244A00803  배상호820807  부산  2400000  1.897741  11.585241  더피플라이프
# 234610  U244A00804  배규태830402  부산  2400000  3.043359  -1.000000  더피플라이프
# 234611  U244A00805  김군자490809  부산  2400000 -0.932611  -1.000000  더피플라이프
# 234612  U244A00806  정일선540801  부산  2400000 -0.191328  -1.000000  더피플라이프
#
#             연체횟수  성별        나이       진행률  상태
# 0      -1.000000   0  0.097929  1.000000   0
# 1      -1.000000   0  0.115928  1.000000   2
# 2       0.838945   0 -0.334043  0.680000   3
# 3      -1.000000   0 -0.316044  1.000000   2
# 4      -1.000000   1  0.547900  1.000000   2
# ...          ...  ..       ...       ...  ..
# 234607  4.574302   0 -0.208051  0.030000   1
# 234609 -0.023060   0 -0.316044  0.716667   1
# 234610 -1.000000   0 -0.334043  1.000000   4
# 234611  2.390555   1  0.277917  0.016667   1
# 234612  1.758418   1  0.187923  0.200000   1
#
# [215094 rows x 12 columns]

# %%
mean = np.mean(list(dfs['상품금액']))
std = np.mean(list(dfs['상품금액']))
dfs['상품금액'] = dfs['상품금액'].apply(lambda x : z_score_normalize(x,mean,std))

# %%
def process_rate(total, last):
    rate = int(last) / int(total)
    return rate

# %%
dfs['진행률'] = dfs.apply(lambda x: process_rate(x['총납입회차'] , x['최종불입회차']), axis=1)

# %%
dfs=dfs[['회원번호','회원이름','주소','상태','상품금액','총불입액','해약금액','담당자','연체횟수','성별','나이','진행률']]
dfs
# Out:
#               회원번호       회원이름  주소     상태  상품금액      총불입액       해약금액     담당자  \
# 0       0022A00001  이옥성590318  경기  만기_해약     2  3.043359  18.730409  더피플라이프
# 1       0072A00001  안성열581125  경기     행사     2  3.043359  -1.000000  더피플라이프
# 2       0072A00002  배준택831121  부산     가입     2  1.749484  -1.000000  더피플라이프
# 3       0072A00003  배민규821023  울산     행사     2  3.043359  -1.000000  더피플라이프
# 4       0072A00006  최금순340728  경기     행사     2  3.043359  -1.000000  더피플라이프
# ...            ...        ...  ..    ...   ...       ...        ...     ...
# 234607  U022A22155  조길찬761012  부산     해약     2 -0.878699  -1.000000  더피플라이프
# 234609  U244A00803  배상호820807  부산     해약     2  1.897741  11.585241  더피플라이프
# 234610  U244A00804  배규태830402  부산     만기     2  3.043359  -1.000000  더피플라이프
# 234611  U244A00805  김군자490809  부산     해약     2 -0.932611  -1.000000  더피플라이프
# 234612  U244A00806  정일선540801  부산     해약     2 -0.191328  -1.000000  더피플라이프
#
#             연체횟수 성별        나이       진행률
# 0      -1.000000  남  0.097929  1.000000
# 1      -1.000000  남  0.115928  1.000000
# 2       0.838945  남 -0.334043  0.680000
# 3      -1.000000  남 -0.316044  1.000000
# 4      -1.000000  여  0.547900  1.000000
# ...          ... ..       ...       ...
# 234607  4.574302  남 -0.208051  0.030000
# 234609 -0.023060  남 -0.316044  0.716667
# 234610 -1.000000  남 -0.334043  1.000000
# 234611  2.390555  여  0.277917  0.016667
# 234612  1.758418  여  0.187923  0.200000
#
# [215094 rows x 12 columns]

# %%
def preprocess_sex(sex):
    if sex =='남':
        return 0
    else:
        return 1

# %%
dfs['성별'] = dfs['성별'].apply(lambda x : preprocess_sex(x))

# %%
def labeling(status):
    if status == '만기_해약':
        return 0
    elif status == '해약':
        return 1
    elif status == '행사':
        return 2
    elif status == '가입':
        return 3
    else: # 만기
        return 4

# %%
dfs['상태'] = dfs['상태'].apply(lambda x : labeling(x))

# %%
dfs=dfs[['회원번호','회원이름','주소','상품금액','총불입액','해약금액','담당자','연체횟수','성별','나이','진행률','상태']]
dfs
# Out:
#               회원번호       회원이름  주소      상품금액      총불입액       해약금액     담당자  \
# 0       0022A00001  이옥성590318  경기 -0.299494  3.043359  18.730409  더피플라이프
# 1       0072A00001  안성열581125  경기 -0.299494  3.043359  -1.000000  더피플라이프
# 2       0072A00002  배준택831121  부산 -0.299494  1.749484  -1.000000  더피플라이프
# 3       0072A00003  배민규821023  울산 -0.299494  3.043359  -1.000000  더피플라이프
# 4       0072A00006  최금순340728  경기 -0.299494  3.043359  -1.000000  더피플라이프
# ...            ...        ...  ..       ...       ...        ...     ...
# 234607  U022A22155  조길찬761012  부산 -0.299494 -0.878699  -1.000000  더피플라이프
# 234609  U244A00803  배상호820807  부산 -0.299494  1.897741  11.585241  더피플라이프
# 234610  U244A00804  배규태830402  부산 -0.299494  3.043359  -1.000000  더피플라이프
# 234611  U244A00805  김군자490809  부산 -0.299494 -0.932611  -1.000000  더피플라이프
# 234612  U244A00806  정일선540801  부산 -0.299494 -0.191328  -1.000000  더피플라이프
#
#             연체횟수  성별        나이       진행률  상태
# 0      -1.000000   0  0.097929  1.000000   0
# 1      -1.000000   0  0.115928  1.000000   2
# 2       0.838945   0 -0.334043  0.680000   3
# 3      -1.000000   0 -0.316044  1.000000   2
# 4      -1.000000   1  0.547900  1.000000   2
# ...          ...  ..       ...       ...  ..
# 234607  4.574302   0 -0.208051  0.030000   1
# 234609 -0.023060   0 -0.316044  0.716667   1
# 234610 -1.000000   0 -0.334043  1.000000   4
# 234611  2.390555   1  0.277917  0.016667   1
# 234612  1.758418   1  0.187923  0.200000   1
#
# [215094 rows x 12 columns]

# %%
pr = dfs.profile_report()
pr.to_file("normalized_report.html")
# Out:
# variables: 100%|██████████| 13/13 [09:38<00:00, 44.53s/it]
# correlations [recoded]: 100%|██████████| 6/6 [00:05<00:00,  1.13it/s]
# interactions [continuous]: 100%|██████████| 64/64 [00:18<00:00,  3.45it/s]
# table: 100%|██████████| 1/1 [00:00<00:00,  1.77it/s]
# missing [matrix]: 100%|██████████| 2/2 [00:00<00:00,  2.44it/s]
# warnings [correlations]: 100%|██████████| 3/3 [00:00<00:00, 1501.18it/s]
# package: 100%|██████████| 1/1 [00:00<00:00, 111.17it/s]
# build report structure: 100%|██████████| 1/1 [00:06<00:00,  6.53s/it]

# %%
dfs.to_csv('normalization.csv')

# %%
df_s = dfs[dfs['해약금액'].between(-2,2)]
# Out:
#               회원번호       회원이름  주소      상품금액      총불입액  해약금액     담당자      연체횟수  \
# 1       0072A00001  안성열581125  경기 -0.299494  3.043359  -1.0  더피플라이프 -1.000000
# 2       0072A00002  배준택831121  부산 -0.299494  1.749484  -1.0  더피플라이프  0.838945
# 3       0072A00003  배민규821023  울산 -0.299494  3.043359  -1.0  더피플라이프 -1.000000
# 4       0072A00006  최금순340728  경기 -0.299494  3.043359  -1.0  더피플라이프 -1.000000
# 6       0072A00021  정성제760210  서울 -0.299494  3.043359  -1.0  더피플라이프 -1.000000
# ...            ...        ...  ..       ...       ...   ...     ...       ...
# 234606  U022A22154  김순옥561026  부산 -0.299494 -0.878699  -1.0  더피플라이프  4.574302
# 234607  U022A22155  조길찬761012  부산 -0.299494 -0.878699  -1.0  더피플라이프  4.574302
# 234610  U244A00804  배규태830402  부산 -0.299494  3.043359  -1.0  더피플라이프 -1.000000
# 234611  U244A00805  김군자490809  부산 -0.299494 -0.932611  -1.0  더피플라이프  2.390555
# 234612  U244A00806  정일선540801  부산 -0.299494 -0.191328  -1.0  더피플라이프  1.758418
#
#         성별        나이       진행률  상태
# 1        0  0.115928  1.000000   2
# 2        0 -0.334043  0.680000   3
# 3        0 -0.316044  1.000000   2
# 4        1  0.547900  1.000000   2
# 6        0 -0.208051  1.000000   4
# ...     ..       ...       ...  ..
# 234606   1  0.151926  0.030000   1
# 234607   0 -0.208051  0.030000   1
# 234610   0 -0.334043  1.000000   4
# 234611   1  0.277917  0.016667   1
# 234612   1  0.187923  0.200000   1
#
# [197664 rows x 12 columns]

# %%
dfs.hist(bins=50)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000019700B04488>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000019705DD0948>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001970CC386C8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001970CC46708>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000019707F35EC8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000019707FBD488>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000019709FED8C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001970A074808>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001970A083308>]],
#       dtype=object)

# %%
dfs.describe()
# Out:
#                상품금액          총불입액          해약금액          연체횟수             성별  \
# count  2.150940e+05  2.150940e+05  2.150940e+05  2.150940e+05  215094.000000
# mean  -5.338304e-17 -9.725226e-17  2.959851e-17 -1.247366e-16       0.527318
# std    2.108972e-01  1.364241e+00  3.590348e+00  2.133398e+00       0.499254
# min   -7.986044e-01 -9.987365e-01 -1.000000e+00 -2.668776e+01       0.000000
# 25%   -1.827425e-01 -9.241870e-01 -1.000000e+00 -1.000000e+00       0.000000
# 50%    1.383229e-01 -5.956641e-01 -1.000000e+00 -1.000000e+00       1.000000
# 75%    1.383229e-01  1.083984e-02 -1.000000e+00  9.538792e-01       1.000000
# max    1.597711e+00  7.221497e+00  3.833903e+01  5.838577e+00       1.000000
#
#                  나이            진행률             상태
# count  2.150940e+05  215094.000000  215094.000000
# mean  -5.021177e-18       0.220277       2.168522
# std    2.560016e-01       0.329712       1.063133
# min   -6.220244e-01       0.002564       0.000000
# 25%   -1.720535e-01       0.012000       1.000000
# 50%    7.934855e-03       0.069231       3.000000
# 75%    1.699244e-01       0.172222       3.000000
# max    1.159860e+00       1.251282       4.000000
