# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
import pandas as pd
from sklearn.metrics import accuracy_score
import sklearn
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

df2018 = pd.read_csv('normalization_zscore_2005_2018_result.csv')
df2019 = pd.read_csv('normalization_zscore_2019_only_result.csv')
# 이상치 제거 df = df[df['123'].between(-2,2)]

# %%
pd.concat([df18_0, df18_1, df18_2, df18_3, df18_4])

# %%
df2018['상태'].value_counts()
# 3: 가입, 1: 해약, 4: 만기, 2: 행사, 0: 만기_해약
# Out:
# 3    194564
# 1    121534
# 2     11003
# 4     10785
# 0      6159
# Name: 상태, dtype: int64

# %%
# 학습할 2005 ~ 2018년 데이터를 언더샘플링
df18_0 = df2018[df2018['상태']==0].sample(n=6000)
df18_1 = df2018[df2018['상태']==1].sample(n=6000)
df18_2 = df2018[df2018['상태']==2].sample(n=6000)
df18_3 = df2018[df2018['상태']==3].sample(n=6000)
df18_4 = df2018[df2018['상태']==4].sample(n=6000)

# %%
# 샘플링한 데이터 합침
df2018_1st = pd.concat([df18_0, df18_1, df18_2, df18_3, df18_4])
df2018_1st.head(5)
# Out:
#              이름번호  성별        나이  진행률      상품금액      잔여금액      연체횟수      가입기간  \
# 211208  최순임790521   1 -0.706352  1.0 -1.657074 -3.463478 -0.545483  2.704193
# 146496  신경실690410   1 -0.035821  1.0 -2.221122 -3.228219 -0.545483  2.810636
# 237047  변영숙531230   1  1.037030  1.0 -1.657074 -3.463478 -0.545483  2.684736
# 177288  최세춘640313   0  0.299445  1.0 -1.657074 -3.463478 -0.545483  2.691603
# 20218   김대준740609   0 -0.371087  1.0 -2.221122 -3.228219 -0.545483  2.714494
#
#                                최종불입일자  계좌수  상태
# 211208  16440 days 00:00:00.000000000    0   0
# 146496  16792 days 00:00:00.000000000    1   0
# 237047  17367 days 00:00:00.000000000    0   0
# 177288  17414 days 00:00:00.000000000    0   0
# 20218   16246 days 00:00:00.000000000    1   0

# %%
# 두번째 샘플링
df18_0 = df2018[df2018['상태']==0].sample(n=6000)
df18_1 = df2018[df2018['상태']==1].sample(n=6000)
df18_2 = df2018[df2018['상태']==2].sample(n=6000)
df18_3 = df2018[df2018['상태']==3].sample(n=6000)
df18_4 = df2018[df2018['상태']==4].sample(n=6000)

# %%
df2018_2nd = pd.concat([df18_0, df18_1, df18_2, df18_3, df18_4])
df2018_2nd.head(5)
# Out:
#              이름번호  성별        나이  진행률      상품금액      잔여금액      연체횟수      가입기간  \
# 96931   김영근731003   0 -0.304033  1.0 -2.221122 -3.228219 -0.545483  2.685880
# 67756   이태욱720829   0 -0.236980  1.0 -2.221122 -3.228219 -0.545483  2.719072
# 166117  이경윤630725   1  0.366498  1.0 -1.657074 -3.463478 -0.545483  2.674435
# 18666   최동협681010   0  0.031232  1.0 -1.657074 -3.463478 -0.545483  2.700760
# 8607    백영진751220   0 -0.438140  1.0 -2.221122 -3.228219 -0.545483  2.703049
#
#                                최종불입일자  계좌수  상태
# 96931   16409 days 00:00:00.000000000    0   0
# 67756   16370 days 00:00:00.000000000    1   0
# 166117  17296 days 00:00:00.000000000    1   0
# 18666   16672 days 00:00:00.000000000    1   0
# 8607    16276 days 00:00:00.000000000    1   0

# %%
# 세번째 샘플링
df18_0 = df2018[df2018['상태']==0].sample(n=6000)
df18_1 = df2018[df2018['상태']==1].sample(n=6000)
df18_2 = df2018[df2018['상태']==2].sample(n=6000)
df18_3 = df2018[df2018['상태']==3].sample(n=6000)
df18_4 = df2018[df2018['상태']==4].sample(n=6000)

# %%
df2018_3rd = pd.concat([df18_0, df18_1, df18_2, df18_3, df18_4])
df2018_3rd.head(5)
# Out:
#              이름번호  성별        나이  진행률      상품금액      잔여금액      연체횟수      가입기간  \
# 332992  주성희670102   1  0.098286  1.0 -0.851290 -3.794634 -0.545483  1.303264
# 158737  김덕림770113   0 -0.572246  1.0 -2.221122 -3.228219 -0.545483  2.700760
# 172650  윤두용550518   0  0.902923  1.0 -2.221122 -3.228219 -0.545483  2.729373
# 226551  한미옥660719   1  0.165339  1.0 -1.119885 -3.687009 -0.545483  2.688169
# 89548   최수현791126   0 -0.706352  1.0 -1.657074 -3.463478 -0.545483  2.680158
#
#                                최종불입일자  계좌수  상태
# 332992  15048 days 00:00:00.000000000    1   0
# 158737  16237 days 00:00:00.000000000    2   0
# 172650  16216 days 00:00:00.000000000    0   0
# 226551  17595 days 00:00:00.000000000    0   0
# 89548   18064 days 00:00:00.000000000    0   0

# %%
# 네번째 샘플링
df18_0 = df2018[df2018['상태']==0].sample(n=6000)
df18_1 = df2018[df2018['상태']==1].sample(n=6000)
df18_2 = df2018[df2018['상태']==2].sample(n=6000)
df18_3 = df2018[df2018['상태']==3].sample(n=6000)
df18_4 = df2018[df2018['상태']==4].sample(n=6000)

# %%
df2018_4th = pd.concat([df18_0, df18_1, df18_2, df18_3, df18_4])
df2018_4th.head(5)
# Out:
#              이름번호  성별        나이  진행률      상품금액      잔여금액      연체횟수      가입기간  \
# 270147  반성규510807   0  1.171136  1.0 -1.657074 -3.463478 -0.545483  2.690459
# 340379  김해련800616   1 -0.773405  1.0 -3.819260 -2.223365 -0.545483 -0.760359
# 171387  안복모791217   0 -0.706352  1.0 -1.657074 -3.463478 -0.545483  3.619833
# 341622  공명식740609   0 -0.371087  1.0 -3.953557 -2.122293 -0.545483 -0.760359
# 77890   박순예630613   1  0.366498  1.0 -2.221122 -3.228219 -0.545483  2.692748
#
#                                최종불입일자  계좌수  상태
# 270147  17281 days 00:00:00.000000000    0   0
# 340379  13718 days 00:00:00.000000000    0   0
# 171387  18011 days 00:00:00.000000000    0   0
# 341622  13510 days 00:00:00.000000000    0   0
# 77890   16185 days 00:00:00.000000000    0   0

# %%
# 다섯번째 샘플링
df18_0 = df2018[df2018['상태']==0].sample(n=6000)
df18_1 = df2018[df2018['상태']==1].sample(n=6000)
df18_2 = df2018[df2018['상태']==2].sample(n=6000)
df18_3 = df2018[df2018['상태']==3].sample(n=6000)
df18_4 = df2018[df2018['상태']==4].sample(n=6000)

# %%
df2018_5th = pd.concat([df18_0, df18_1, df18_2, df18_3, df18_4])
df2018_5th.head(5)
# Out:
#              이름번호  성별        나이  진행률      상품금액      잔여금액      연체횟수      가입기간  \
# 68973   문대근770115   0 -0.572246  1.0 -2.221122 -3.228219 -0.545483  2.691603
# 218720  김경애530526   1  1.037030  1.0 -1.657074 -3.463478 -0.545483  2.715639
# 108606  정기봉490228   0  1.305242  1.0 -1.119885 -3.687009 -0.545483  2.714494
# 120534  김미진680104   1  0.031232  1.0 -1.657074 -3.463478 -0.545483  2.680158
# 305770  조성애621204   1  0.433551  1.0 -3.953557 -2.122293 -0.545483 -0.760359
#
#                                최종불입일자  계좌수  상태
# 68973   16414 days 00:00:00.000000000    1   0
# 218720  17464 days 00:00:00.000000000    0   0
# 108606  17588 days 00:00:00.000000000    0   0
# 120534  17182 days 00:00:00.000000000    0   0
# 305770  13376 days 00:00:00.000000000    1   0

# %%
# 여섯번째 샘플링
df18_0 = df2018[df2018['상태']==0].sample(n=6000)
df18_1 = df2018[df2018['상태']==1].sample(n=6000)
df18_2 = df2018[df2018['상태']==2].sample(n=6000)
df18_3 = df2018[df2018['상태']==3].sample(n=6000)
df18_4 = df2018[df2018['상태']==4].sample(n=6000)

# %%
df2018_6th = pd.concat([df18_0, df18_1, df18_2, df18_3, df18_4])
df2018_6th.head(5)
# Out:
#              이름번호  성별        나이  진행률      상품금액      잔여금액      연체횟수      가입기간  \
# 122429  전재훈770815   0 -0.572246  1.0 -3.953557 -2.122293 -0.545483 -0.760359
# 342249  김주수561225   0  0.835870  1.0 -3.819260 -2.223365 -0.545483 -0.760359
# 211208  최순임790521   1 -0.706352  1.0 -1.657074 -3.463478 -0.545483  2.704193
# 341119  김동희830209   0 -0.974565  1.0 -3.953557 -2.550727 -0.545483 -0.760359
# 98294   최지원820123   1 -0.907512  1.0 -0.448398 -3.966422 -0.545483  1.222001
#
#                                최종불입일자  계좌수  상태
# 122429  13221 days 00:00:00.000000000    0   0
# 342249  14640 days 00:00:00.000000000    0   0
# 211208  16440 days 00:00:00.000000000    0   0
# 341119  13439 days 00:00:00.000000000    0   0
# 98294   15516 days 00:00:00.000000000    0   0

# %%
# 일곱번째 샘플링
df18_0 = df2018[df2018['상태']==0].sample(n=6000)
df18_1 = df2018[df2018['상태']==1].sample(n=6000)
df18_2 = df2018[df2018['상태']==2].sample(n=6000)
df18_3 = df2018[df2018['상태']==3].sample(n=6000)
df18_4 = df2018[df2018['상태']==4].sample(n=6000)

# %%
df2018_7th = pd.concat([df18_0, df18_1, df18_2, df18_3, df18_4])
df2018_7th.head(5)
# Out:
#              이름번호  성별        나이  진행률      상품금액      잔여금액      연체횟수      가입기간  \
# 117588  노춘자550330   1  0.902923  1.0 -1.657074 -3.437861 -0.545483  0.989658
# 3052    박경희530825   0  1.037030  1.0 -2.221122 -3.228219 -0.545483  3.389778
# 172674  안은선550917   0  0.902923  1.0 -1.657074 -3.463478 -0.545483  2.899911
# 165710  안영자600315   1  0.567658  1.0 -0.851290 -3.798774 -0.545483  2.689314
# 139423  이재환540908   0  0.969976  1.0 -2.221122 -3.228219 -0.545483  2.684736
#
#                                최종불입일자  계좌수  상태
# 117588  16220 days 00:00:00.000000000    0   0
# 3052    16885 days 00:00:00.000000000    1   0
# 172674  16643 days 00:00:00.000000000    0   0
# 165710  16353 days 00:00:00.000000000    1   0
# 139423  16581 days 00:00:00.000000000    1   0

# %%
# 여덟번째 샘플링
df18_0 = df2018[df2018['상태']==0].sample(n=6000)
df18_1 = df2018[df2018['상태']==1].sample(n=6000)
df18_2 = df2018[df2018['상태']==2].sample(n=6000)
df18_3 = df2018[df2018['상태']==3].sample(n=6000)
df18_4 = df2018[df2018['상태']==4].sample(n=6000)

# %%
df2018_8th = pd.concat([df18_0, df18_1, df18_2, df18_3, df18_4])
df2018_8th.head(5)
# Out:
#              이름번호  성별        나이  진행률      상품금액      잔여금액      연체횟수      가입기간  \
# 90264    라리841023   1 -1.041618  1.0 -3.819260 -2.667322 -0.545483 -0.760359
# 273032  안미경661120   1  0.165339  1.0 -0.448398 -3.925027 -0.545483  0.924418
# 233246  이점순510616   1  1.171136  1.0 -2.221122 -3.228219 -0.545483  2.727084
# 195906  윤여운750904   0 -0.438140  1.0 -2.221122 -3.228219 -0.545483  2.685880
# 211655  정현숙600328   1  0.567658  1.0 -2.221122 -3.228219 -0.545483  2.697326
#
#                                최종불입일자  계좌수  상태
# 90264   13997 days 00:00:00.000000000    0   0
# 273032  15359 days 00:00:00.000000000    1   0
# 233246  16261 days 00:00:00.000000000    1   0
# 195906  16409 days 00:00:00.000000000    2   0
# 211655  16167 days 00:00:00.000000000    1   0

# %%
# 아홉번째 샘플링
df18_0 = df2018[df2018['상태']==0].sample(n=6000)
df18_1 = df2018[df2018['상태']==1].sample(n=6000)
df18_2 = df2018[df2018['상태']==2].sample(n=6000)
df18_3 = df2018[df2018['상태']==3].sample(n=6000)
df18_4 = df2018[df2018['상태']==4].sample(n=6000)

# %%
df2018_9th = pd.concat([df18_0, df18_1, df18_2, df18_3, df18_4])
df2018_9th.head(5)
# Out:
#              이름번호  성별        나이  진행률      상품금액      잔여금액      연체횟수      가입기간  \
# 200773  김동윤540107   0  0.969976  1.0 -0.851290 -3.793945 -0.545483  1.227724
# 171479  김수영810901   1 -0.840459  1.0 -1.657074 -3.463478 -0.545483  2.680158
# 102847  김종태630106   0  0.366498  1.0 -1.657074 -3.463478 -0.545483  2.690459
# 341351  심재홍820114   0 -0.907512  1.0 -3.953557 -2.122293 -0.545483 -0.760359
# 89353   손남욱780922   0 -0.639299  1.0 -3.953557 -2.122293 -0.545483 -0.760359
#
#                                최종불입일자  계좌수  상태
# 200773  15058 days 00:00:00.000000000    0   0
# 171479  17186 days 00:00:00.000000000    0   0
# 102847  16434 days 00:00:00.000000000    0   0
# 341351  13440 days 00:00:00.000000000    0   0
# 89353   13613 days 00:00:00.000000000    0   0

# %%
# 열번째 샘플링
df18_0 = df2018[df2018['상태']==0].sample(n=6000)
df18_1 = df2018[df2018['상태']==1].sample(n=6000)
df18_2 = df2018[df2018['상태']==2].sample(n=6000)
df18_3 = df2018[df2018['상태']==3].sample(n=6000)
df18_4 = df2018[df2018['상태']==4].sample(n=6000)

# %%
df2018_10th = pd.concat([df18_0, df18_1, df18_2, df18_3, df18_4])
df2018_10th.head(5)
# Out:
#              이름번호  성별        나이  진행률      상품금액      잔여금액      연체횟수      가입기간  \
# 145937  홍순화721003   1 -0.236980  1.0 -1.657074 -3.463478 -0.545483  2.669857
# 265526  이효진850810   1 -1.108671  1.0 -3.819260 -2.667322 -0.545483 -0.760359
# 65140   김종대630310   0  0.366498  1.0 -2.221122 -3.228219 -0.545483  2.690459
# 80781   장윤식770901   0 -0.572246  1.0 -3.953557 -2.122293 -0.545483 -0.760359
# 99585   김양이360812   1  2.176933  1.0 -1.657074 -3.463478 -0.545483  2.688169
#
#                                최종불입일자  계좌수  상태
# 145937  16906 days 00:00:00.000000000    0   0
# 265526  14091 days 00:00:00.000000000    0   0
# 65140   16636 days 00:00:00.000000000    1   0
# 80781   13437 days 00:00:00.000000000    0   0
# 99585   17308 days 00:00:00.000000000    0   0

# %%
df2018_10th.shape
# Out:
# (30000, 10)

# %%
df2018_10th['상태'].value_counts()
# Out:
# 4    6000
# 3    6000
# 2    6000
# 1    6000
# 0    6000
# Name: 상태, dtype: int64

# %%
df2018_1st.to_csv('./randomForest/under_sampling_6000_1st.csv')
df2018_2nd.to_csv('./randomForest/under_sampling_6000_2nd.csv')
df2018_3rd.to_csv('./randomForest/under_sampling_6000_3rd.csv')
df2018_4th.to_csv('./randomForest/under_sampling_6000_4th.csv')
df2018_5th.to_csv('./randomForest/under_sampling_6000_5th.csv')
df2018_6th.to_csv('./randomForest/under_sampling_6000_6th.csv')
df2018_7th.to_csv('./randomForest/under_sampling_6000_7th.csv')
df2018_8th.to_csv('./randomForest/under_sampling_6000_8th.csv')
df2018_9th.to_csv('./randomForest/under_sampling_6000_9th.csv')
df2018_10th.to_csv('./randomForest/under_sampling_6000_10th.csv')

# %%
from sklearn.metrics import accuracy_score, precision_score , recall_score , confusion_matrix
from sklearn.metrics import f1_score 

# accuracy, precision, recall, f1 스코어를 구하기 위한 함수
def get_clf_eval(y_test , pred):
    confusion = confusion_matrix( y_test, pred)
    accuracy = accuracy_score(y_test , pred)
    precision = precision_score(y_test , pred,average='macro')
    recall = recall_score(y_test , pred, average='macro')
    # F1 스코어 추가
    f1 = f1_score(y_test,pred, average='macro')
    print('오차 행렬')
    print(confusion)
    # f1 score print 추가
    print('정확도: {0:.4f}, 정밀도: {1:.4f}, 재현율: {2:.4f}, F1:{3:.4f}'.format(accuracy, precision, recall, f1))

# %%
from sklearn.ensemble import RandomForestClassifier

rf = df2018_1st[['성별', '나이', '진행률', '상품금액', '잔여금액', '연체횟수', '가입기간','계좌수']]
rf.data = rf.values.tolist()
rf.target = df2018_1st[['상태']]

rf.feature_names=['sex','age','process_rate','price','remaining_price','overdue_num','period', 'multi_account']
rf.target_names=['contract','cancellation']
rf.head(3)

# 테스트데이터와 학습데이터를 2:8 비율로 나눠서 학습 진행
X_train , X_test , y_train , y_test = train_test_split(rf.data, rf.target, test_size=0.2,  random_state=32)

rnd_clf = RandomForestClassifier(n_estimators=250, max_depth=9 , n_jobs=-1, random_state=32)
rnd_clf.fit(X_train, y_train)
y_pred_rf = rnd_clf.predict(X_test)

accuracy = accuracy_score(y_test , y_pred_rf)
print('# 1번째 랜덤 포레스트 정확도: {0:.4f}'.format(accuracy))

get_clf_eval(y_test, y_pred_rf)
# Out:
# # 1번째 랜덤 포레스트 정확도: 0.9457
# 오차 행렬
# [[1191    0    0    0    0]
#  [   1 1220    0   17    0]
#  [  11    0 1010    4  153]
#  [  10   51    0 1084    0]
#  [   0    1   78    0 1169]]
# 정확도: 0.9457, 정밀도: 0.9469, 재현율: 0.9453, F1:0.9455

# %%
rf = df2018_2nd[['성별', '나이', '진행률', '상품금액', '잔여금액', '연체횟수', '가입기간','계좌수']]
rf.data = rf.values.tolist()
rf.target = df2018_2nd[['상태']]

rf.feature_names=['sex','age','process_rate','price','remaining_price','overdue_num','period', 'multi_account']
rf.target_names=['contract','cancellation']
rf.head(3)

# 테스트데이터와 학습데이터를 2:8 비율로 나눠서 학습 진행
X_train , X_test , y_train , y_test = train_test_split(rf.data, rf.target, test_size=0.2,  random_state=32)

rnd_clf = RandomForestClassifier(n_estimators=250, max_depth=9 , n_jobs=-1, random_state=32)
rnd_clf.fit(X_train, y_train)
y_pred_rf = rnd_clf.predict(X_test)

accuracy = accuracy_score(y_test , y_pred_rf)
print('# 2번째 랜덤 포레스트 정확도: {0:.4f}'.format(accuracy))

get_clf_eval(y_test, y_pred_rf)
# Out:
# # 2번째 랜덤 포레스트 정확도: 0.9460
# 오차 행렬
# [[1191    0    0    0    0]
#  [   0 1211    0   27    0]
#  [  16    1 1029    5  127]
#  [  10   58    0 1077    0]
#  [   0    0   80    0 1168]]
# 정확도: 0.9460, 정밀도: 0.9466, 재현율: 0.9456, F1:0.9458

# %%
rf = df2018_3rd[['성별', '나이', '진행률', '상품금액', '잔여금액', '연체횟수', '가입기간','계좌수']]
rf.data = rf.values.tolist()
rf.target = df2018_3rd[['상태']]

rf.feature_names=['sex','age','process_rate','price','remaining_price','overdue_num','period', 'multi_account']
rf.target_names=['contract','cancellation']
rf.head(3)

# 테스트데이터와 학습데이터를 2:8 비율로 나눠서 학습 진행
X_train , X_test , y_train , y_test = train_test_split(rf.data, rf.target, test_size=0.2,  random_state=32)

rnd_clf = RandomForestClassifier(n_estimators=250, max_depth=9 , n_jobs=-1, random_state=32)
rnd_clf.fit(X_train, y_train)
y_pred_rf = rnd_clf.predict(X_test)

accuracy = accuracy_score(y_test , y_pred_rf)
print('# 3번째 랜덤 포레스트 정확도: {0:.4f}'.format(accuracy))

get_clf_eval(y_test, y_pred_rf)
# Out:
# # 3번째 랜덤 포레스트 정확도: 0.9485
# 오차 행렬
# [[1187    0    4    0    0]
#  [   0 1222    0   16    0]
#  [  14    0 1013    3  148]
#  [  11   44    0 1090    0]
#  [   0    0   69    0 1179]]
# 정확도: 0.9485, 정밀도: 0.9497, 재현율: 0.9481, F1:0.9483

# %%
rf = df2018_4th[['성별', '나이', '진행률', '상품금액', '잔여금액', '연체횟수', '가입기간','계좌수']]
rf.data = rf.values.tolist()
rf.target = df2018_4th[['상태']]

rf.feature_names=['sex','age','process_rate','price','remaining_price','overdue_num','period', 'multi_account']
rf.target_names=['contract','cancellation']
rf.head(3)

# 테스트데이터와 학습데이터를 2:8 비율로 나눠서 학습 진행
X_train , X_test , y_train , y_test = train_test_split(rf.data, rf.target, test_size=0.2,  random_state=32)

rnd_clf = RandomForestClassifier(n_estimators=250, max_depth=9 , n_jobs=-1, random_state=32)
rnd_clf.fit(X_train, y_train)
y_pred_rf = rnd_clf.predict(X_test)

accuracy = accuracy_score(y_test , y_pred_rf)
print('# 4번째 랜덤 포레스트 정확도: {0:.4f}'.format(accuracy))

get_clf_eval(y_test, y_pred_rf)
# Out:
# # 4번째 랜덤 포레스트 정확도: 0.9477
# 오차 행렬
# [[1190    0    1    0    0]
#  [   0 1218    0   20    0]
#  [  12    0 1011    2  153]
#  [   7   47    1 1090    0]
#  [   0    0   71    0 1177]]
# 정확도: 0.9477, 정밀도: 0.9490, 재현율: 0.9473, F1:0.9476

# %%
rf = df2018_5th[['성별', '나이', '진행률', '상품금액', '잔여금액', '연체횟수', '가입기간','계좌수']]
rf.data = rf.values.tolist()
rf.target = df2018_5th[['상태']]

rf.feature_names=['sex','age','process_rate','price','remaining_price','overdue_num','period', 'multi_account']
rf.target_names=['contract','cancellation']
rf.head(3)

# 테스트데이터와 학습데이터를 2:8 비율로 나눠서 학습 진행
X_train , X_test , y_train , y_test = train_test_split(rf.data, rf.target, test_size=0.2,  random_state=32)

rnd_clf = RandomForestClassifier(n_estimators=250, max_depth=9 , n_jobs=-1, random_state=32)
rnd_clf.fit(X_train, y_train)
y_pred_rf = rnd_clf.predict(X_test)

accuracy = accuracy_score(y_test , y_pred_rf)
print('# 5번째 랜덤 포레스트 정확도: {0:.4f}'.format(accuracy))

get_clf_eval(y_test, y_pred_rf)
# Out:
# # 5번째 랜덤 포레스트 정확도: 0.9473
# 오차 행렬
# [[1191    0    0    0    0]
#  [   0 1217    0   21    0]
#  [  10    0 1007    4  157]
#  [  14   41    1 1089    0]
#  [   0    0   68    0 1180]]
# 정확도: 0.9473, 정밀도: 0.9487, 재현율: 0.9469, F1:0.9472

# %%
rf = df2018_6th[['성별', '나이', '진행률', '상품금액', '잔여금액', '연체횟수', '가입기간','계좌수']]
rf.data = rf.values.tolist()
rf.target = df2018_6th[['상태']]

rf.feature_names=['sex','age','process_rate','price','remaining_price','overdue_num','period', 'multi_account']
rf.target_names=['contract','cancellation']
rf.head(3)

# 테스트데이터와 학습데이터를 2:8 비율로 나눠서 학습 진행
X_train , X_test , y_train , y_test = train_test_split(rf.data, rf.target, test_size=0.2,  random_state=32)

rnd_clf = RandomForestClassifier(n_estimators=250, max_depth=9 , n_jobs=-1, random_state=32)
rnd_clf.fit(X_train, y_train)
y_pred_rf = rnd_clf.predict(X_test)

accuracy = accuracy_score(y_test , y_pred_rf)
print('# 6번째 랜덤 포레스트 정확도: {0:.4f}'.format(accuracy))

get_clf_eval(y_test, y_pred_rf)
# Out:
# # 6번째 랜덤 포레스트 정확도: 0.9485
# 오차 행렬
# [[1188    0    3    0    0]
#  [   0 1213    0   25    0]
#  [  13    0 1019    6  140]
#  [   9   44    1 1091    0]
#  [   0    0   68    0 1180]]
# 정확도: 0.9485, 정밀도: 0.9494, 재현율: 0.9481, F1:0.9483

# %%
rf = df2018_7th[['성별', '나이', '진행률', '상품금액', '잔여금액', '연체횟수', '가입기간','계좌수']]
rf.data = rf.values.tolist()
rf.target = df2018_7th[['상태']]

rf.feature_names=['sex','age','process_rate','price','remaining_price','overdue_num','period', 'multi_account']
rf.target_names=['contract','cancellation']
rf.head(3)

# 테스트데이터와 학습데이터를 2:8 비율로 나눠서 학습 진행
X_train , X_test , y_train , y_test = train_test_split(rf.data, rf.target, test_size=0.2,  random_state=32)

rnd_clf = RandomForestClassifier(n_estimators=250, max_depth=9 , n_jobs=-1, random_state=32)
rnd_clf.fit(X_train, y_train)
y_pred_rf = rnd_clf.predict(X_test)

accuracy = accuracy_score(y_test , y_pred_rf)
print('# 7번째 랜덤 포레스트 정확도: {0:.4f}'.format(accuracy))

get_clf_eval(y_test, y_pred_rf)
# Out:
# # 7번째 랜덤 포레스트 정확도: 0.9527
# 오차 행렬
# [[1190    0    1    0    0]
#  [   0 1210    0   28    0]
#  [  13    0 1038    3  124]
#  [  14   40    1 1090    0]
#  [   0    0   60    0 1188]]
# 정확도: 0.9527, 정밀도: 0.9535, 재현율: 0.9523, F1:0.9525

# %%
rf = df2018_8th[['성별', '나이', '진행률', '상품금액', '잔여금액', '연체횟수', '가입기간','계좌수']]
rf.data = rf.values.tolist()
rf.target = df2018_8th[['상태']]

rf.feature_names=['sex','age','process_rate','price','remaining_price','overdue_num','period', 'multi_account']
rf.target_names=['contract','cancellation']
rf.head(3)

# 테스트데이터와 학습데이터를 2:8 비율로 나눠서 학습 진행
X_train , X_test , y_train , y_test = train_test_split(rf.data, rf.target, test_size=0.2,  random_state=32)

rnd_clf = RandomForestClassifier(n_estimators=250, max_depth=9 , n_jobs=-1, random_state=32)
rnd_clf.fit(X_train, y_train)
y_pred_rf = rnd_clf.predict(X_test)

accuracy = accuracy_score(y_test , y_pred_rf)
print('# 8번째 랜덤 포레스트 정확도: {0:.4f}'.format(accuracy))

get_clf_eval(y_test, y_pred_rf)
# Out:
# # 8번째 랜덤 포레스트 정확도: 0.9495
# 오차 행렬
# [[1189    0    2    0    0]
#  [   0 1218    0   20    0]
#  [  12    0 1026    3  137]
#  [   8   49    0 1088    0]
#  [   0    0   72    0 1176]]
# 정확도: 0.9495, 정밀도: 0.9505, 재현율: 0.9491, F1:0.9494

# %%
rf = df2018_9th[['성별', '나이', '진행률', '상품금액', '잔여금액', '연체횟수', '가입기간','계좌수']]
rf.data = rf.values.tolist()
rf.target = df2018_9th[['상태']]

rf.feature_names=['sex','age','process_rate','price','remaining_price','overdue_num','period', 'multi_account']
rf.target_names=['contract','cancellation']
rf.head(3)

# 테스트데이터와 학습데이터를 2:8 비율로 나눠서 학습 진행
X_train , X_test , y_train , y_test = train_test_split(rf.data, rf.target, test_size=0.2,  random_state=32)

rnd_clf = RandomForestClassifier(n_estimators=250, max_depth=9 , n_jobs=-1, random_state=32)
rnd_clf.fit(X_train, y_train)
y_pred_rf = rnd_clf.predict(X_test)

accuracy = accuracy_score(y_test , y_pred_rf)
print('# 9번째 랜덤 포레스트 정확도: {0:.4f}'.format(accuracy))

get_clf_eval(y_test, y_pred_rf)
# Out:
# # 9번째 랜덤 포레스트 정확도: 0.9487
# 오차 행렬
# [[1189    0    2    0    0]
#  [   0 1215    0   23    0]
#  [  11    0 1020    4  143]
#  [   8   51    1 1085    0]
#  [   0    0   65    0 1183]]
# 정확도: 0.9487, 정밀도: 0.9499, 재현율: 0.9482, F1:0.9485

# %%
rf = df2018_10th[['성별', '나이', '진행률', '상품금액', '잔여금액', '연체횟수', '가입기간','계좌수']]
rf.data = rf.values.tolist()
rf.target = df2018_10th[['상태']]

rf.feature_names=['sex','age','process_rate','price','remaining_price','overdue_num','period', 'multi_account']
rf.target_names=['contract','cancellation']
rf.head(3)

# 테스트데이터와 학습데이터를 2:8 비율로 나눠서 학습 진행
X_train , X_test , y_train , y_test = train_test_split(rf.data, rf.target, test_size=0.2,  random_state=32)

rnd_clf = RandomForestClassifier(n_estimators=250, max_depth=9 , n_jobs=-1, random_state=32)
rnd_clf.fit(X_train, y_train)
y_pred_rf = rnd_clf.predict(X_test)

accuracy = accuracy_score(y_test , y_pred_rf)
print('# 10번째 랜덤 포레스트 정확도: {0:.4f}'.format(accuracy))

get_clf_eval(y_test, y_pred_rf)
# Out:
# # 10번째 랜덤 포레스트 정확도: 0.9482
# 오차 행렬
# [[1188    0    3    0    0]
#  [   0 1208    0   30    0]
#  [  15    0 1020    5  138]
#  [  11   39    1 1094    0]
#  [   0    0   69    0 1179]]
# 정확도: 0.9482, 정밀도: 0.9489, 재현율: 0.9479, F1:0.9480

# %%
import seaborn as sns
ftr_importances_values = rnd_clf.feature_importances_
ftr_importances = pd.Series(ftr_importances_values,index=rf.feature_names)
ftr_top20 = ftr_importances.sort_values(ascending=False)[:8]

plt.figure(figsize=(8,6))
plt.title('RandomForest Classifier Feature Weight')
sns.barplot(x=ftr_top20 , y = ftr_top20.index)
plt.show()
